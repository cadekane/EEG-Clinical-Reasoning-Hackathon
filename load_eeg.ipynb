# %%
import mne
file_path = "datasets/ds004504_eeg/sub-001/eeg/sub-001_task-eyesclosed_eeg.set"
raw = mne.io.read_raw_eeglab(file_path, preload=True)
print(raw.ch_names)       # see exactly what names are in the file
print(raw.info['sfreq'])  # confirm sampling rate
print(raw.times[-1])      # total recording length in seconds
# Out:
# ['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz']
# 500.0
# 599.798

# %%
import pandas as pd
df = pd.read_csv("datasets/ds004504_eeg/participants.tsv", sep='\t')
print(df.head(10))
print(df.columns.tolist())
# Out:
#   participant_id Gender  Age Group  MMSE
# 0        sub-001      F   57     A    16
# 1        sub-002      F   78     A    22
# 2        sub-003      M   70     A    14
# 3        sub-004      F   67     A    20
# 4        sub-005      M   70     A    22
# 5        sub-006      F   61     A    14
# 6        sub-007      F   79     A    20
# 7        sub-008      M   62     A    16
# 8        sub-009      F   77     A    23
# 9        sub-010      M   69     A    20
# ['participant_id', 'Gender', 'Age', 'Group', 'MMSE']
